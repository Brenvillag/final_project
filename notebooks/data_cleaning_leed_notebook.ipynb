# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("../data/raw/top_leed_certifications_2024-2025.csv")
df.head()
# Out:
#            ID Isconfidential                              ProjectName  \
# 0  1000011028             No               Clarksburg Fire Station 35
# 1  1000011315             No  Moultrie Courthouse - C Street Addition
# 2  1000012868             No    Petrocelli Surgical Pavilion Addition
# 3  1000017965            Yes                             Confidential
# 4  1000020194             No                  UMD New Cole Fieldhouse
#
#                 Street          City State       Zipcode Country  \
# 0  23420 Frederick Rd.    Clarksburg    MD         20871      US
# 1     501 C Street, NW    Washington    DC         20001      US
# 2  300 Community Drive     Manhasset    NY         11030      US
# 3         Confidential  Confidential    MD  Confidential      US
# 4     4090 Union Drive  College Park    MD         20742      US
#
#   LEEDSystemVersionDisplayName  PointsAchieved CertLevel          CertDate  \
# ...

# %%
df.shape
# Out:
# (2066, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2066 entries, 0 to 2065
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            2066 non-null   int64
#  1   Isconfidential                2066 non-null   object
#  2   ProjectName                   2066 non-null   object
#  3   Street                        2066 non-null   object
#  4   City                          2066 non-null   object
#  5   State                         1884 non-null   object
#  6   Zipcode                       2065 non-null   object
#  7   Country                       2066 non-null   object
#  8   LEEDSystemVersionDisplayName  2066 non-null   object
#  9   PointsAchieved                2066 non-null   int64
#  10  CertLevel                     2066 non-null   object
#  11  CertDate                      2066 non-null   object
# ...

# %%
df[['Zipcode','State', 'OwnerTypes']] = df[['Zipcode','State', 'OwnerTypes']].fillna('N/A')
df
# Out:
#               ID Isconfidential                              ProjectName  \
# 0     1000011028             No               Clarksburg Fire Station 35
# 1     1000011315             No  Moultrie Courthouse - C Street Addition
# 2     1000012868             No    Petrocelli Surgical Pavilion Addition
# 3     1000017965            Yes                             Confidential
# 4     1000020194             No                  UMD New Cole Fieldhouse
# ...          ...            ...                                      ...
# 2061  1000215829             No         Canny Elevator Technology Center
# 2062  1000216346             No                         Mashreq Bank DOZ
# 2063  1000216631             No      Commerzone Kharadi R1/Building No 3
# 2064  1000217225             No  Kama Ayurveda Factory, Crafting Greener
# 2065  1000217729             No                         Central Square I
#
#                                         Street          City        State  \
# ...

# %%
df['UnitOfMeasurement'].unique()
# Out:
# array(['Sq ft', 'Sq m'], dtype=object)

# %% [markdown]
# Convert 1 sqft = 0.093 sqmt for GrossFloorArea

# %%
mask_sqft = df['UnitOfMeasurement'].str.lower() == 'sqft'
df.loc[mask_sqft, 'GrossFloorArea'] = (df.loc[mask_sqft, 'GrossFloorArea'] * 0.092903).round(2)
df
# Out:
#               ID Isconfidential                              ProjectName  \
# 0     1000011028             No               Clarksburg Fire Station 35
# 1     1000011315             No  Moultrie Courthouse - C Street Addition
# 2     1000012868             No    Petrocelli Surgical Pavilion Addition
# 3     1000017965            Yes                             Confidential
# 4     1000020194             No                  UMD New Cole Fieldhouse
# ...          ...            ...                                      ...
# 2061  1000215829             No         Canny Elevator Technology Center
# 2062  1000216346             No                         Mashreq Bank DOZ
# 2063  1000216631             No      Commerzone Kharadi R1/Building No 3
# 2064  1000217225             No  Kama Ayurveda Factory, Crafting Greener
# 2065  1000217729             No                         Central Square I
#
#                                         Street          City        State  \
# ...

# %%
df= df.rename(columns={'LEEDSystemVersionDisplayName': 'RatingSystem', 'GrossFloorArea':'GrossFloorAreaSqm'})
df_leed = df.drop(['Isconfidential', 'Street', 'OwnerOrganization', 'OwnerTypes', 'TotalPropArea', 'RegistrationDate', 'UnitOfMeasurement'], axis=1)
df_leed
# Out:
#               ID                              ProjectName          City  \
# 0     1000011028               Clarksburg Fire Station 35    Clarksburg
# 1     1000011315  Moultrie Courthouse - C Street Addition    Washington
# 2     1000012868    Petrocelli Surgical Pavilion Addition     Manhasset
# 3     1000017965                             Confidential  Confidential
# 4     1000020194                  UMD New Cole Fieldhouse  College Park
# ...          ...                                      ...           ...
# 2061  1000215829         Canny Elevator Technology Center        Suzhou
# 2062  1000216346                         Mashreq Bank DOZ         Dubai
# 2063  1000216631      Commerzone Kharadi R1/Building No 3          Pune
# 2064  1000217225  Kama Ayurveda Factory, Crafting Greener      Tiruppur
# 2065  1000217729                         Central Square I       Chennai
#
#             State       Zipcode Country       RatingSystem  PointsAchieved  \
# ...

# %%
df_leed['State'].unique()
# Out:
# array(['MD', 'DC', 'NY', 'RJ', 'CA', 'IL', 'VA', 'WA', 'PA', 'GU', 'TN',
#        'Istanbul', 'TX', 'FL', 'AE', 'MI', 'NT', 'Hunan', 'OH', 'Haryana',
#        'MA', 'IN', 'N/A', 'NH', 'MO', 'MN', 'Guangdong', 'NC', 'DE', 'MT',
#        'TS', 'OR', 'Karnataka', 'Hainan', 'GA', 'MB', 'AB', 'HI', 'ON',
#        'Kyonggi-do', 'NS', 'QC', 'CO', 'CT', 'Cadiz', 'AL', 'KY', 'NJ',
#        'BC', 'UT', 'Goa', 'IA', 'Kyongsang-bukto', 'QRO', 'VT', 'SP',
#        'Salamanca', 'Madrid', 'WI', 'MS', 'Barcelona', 'Tekirdag', 'BO',
#        'VI', 'Antalya', 'TG', 'Sichuan', 'LA', 'NM', 'NV', 'Chongqing',
#        'RM', 'Maharashtra', 'VE', 'Shaanxi', 'ME', 'SC', 'AZ', 'Jiangsu',
#        'Tamil Nadu', 'AQ', 'TO', 'Shandong', 'KS', 'SK', 'SD',
#        'Tarragona', 'PR', 'Burdur', 'Zhejiang', 'Konya', 'PD', 'Gujarat',
#        'Uttar Pradesh', 'Amasya', 'FI', 'NE', 'NO', 'Gaziantep', 'BG',
#        'PE', 'BS', 'Adana', 'Vizcaya', 'Yalova', 'Kirklareli', 'ID', 'AR',
# ...

# %%
df_leed['City'].unique()
# Out:
# array(['Clarksburg', 'Washington', 'Manhasset', 'Confidential',
#        'College Park', 'Seropedica', 'Los Angeles', 'Palatine', 'Wise',
#        'Ellensburg', 'Pittsburgh', 'Riva Del Garda', 'New York',
#        'Istanbul', 'Queens', 'Grayslake', 'Silver Spring', 'Willows',
#        'Johnstown', 'Joilet', 'Miami', 'Redding', 'French Camp',
#        'BROOKLYN', 'Leesburg', 'Warren', 'Hong Kong', 'Fishersville',
#        'Radford', 'Changsha', 'Gainesville', 'Arlington', 'San Francisco',
#        'Faridabad', 'Sherborn', 'Bloomington', 'Nashville', 'Lubbock',
#        'Blacksburg', 'Richmond', 'Bowie', 'North Bend', 'Sylmar',
#        'Boston', 'Hayward', 'Charlottesville', 'Minneapolis', 'Watertown',
#        'Towson', 'Shenzhen', 'Syracuse', 'Lewiston', 'Newport News',
#        'Charlotte', 'Long Beach', 'Dover', 'Fairfax', 'Sterling',
#        'Malmstrom', 'Sweetwater', 'Williamsburg', 'La Jolla',
#        'Chevy Chase', 'Trieste', 'Warrenton', 'Laurel', 'Christmas',
# ...

# %%
city_mapping = {
    'alcobendas': 'Alcobendas', 'antalya': 'Antalya', 'bangalore': 'Bangalore', 'beijing': 'Beijing', 'bengaluru': 'Bengaluru', 'changchun': 'Changchun',
    'changsha': 'Changsha', 'chengdu': 'Chengdu', 'chennai': 'Chennai', 'chongqing': 'Chongqing', 'davis': 'Davis', 'dubai': 'Dubai', 
    'gainesville': 'Gainesville', 'haerbin': 'Haerbin', 'hk': 'HK', 'istanbul': 'Istanbul', 'izmir': 'Izmir', 'jiaxing': 'Jiaxing',
    'jinan': 'Jinan', 'kunshan': 'Kunshan', 'madrid': 'Madrid', 'milan': 'Milan', 'mumbai': 'Mumbai', 'nanchang': 'Nanchang', 'nanjing': 'Nanjing',
    'noida': 'Noida', 'ottawa': 'Ottawa', 'pozuelo de alarcon': 'Pozuelo de Alarcon', 'qingdao': 'Qingdao', 'roma': 'Roma', 'shanghai': 'Shanghai',
    'surat': 'Surat', 'suzhou': 'Suzhou', 'taicang': 'Taicang', 'tianjin': 'Tianjin', 'wuhan': 'Wuhan', 'wuxi': 'Wuxi', 'xian': 'Xian','zhengzhou': 'Zhengzhou',
    'Brooklyn': 'Brooklyn'}

df_leed['city_mapping'] = df_leed['City'].str.strip().str.lower()

df_leed['City'] = df_leed['city_mapping'].map(city_mapping).fillna(df_leed['City'])

df_leed.drop(columns='city_mapping', inplace=True)
df_leed
# Out:
#               ID                              ProjectName          City  \
# 0     1000011028               Clarksburg Fire Station 35    Clarksburg
# 1     1000011315  Moultrie Courthouse - C Street Addition    Washington
# 2     1000012868    Petrocelli Surgical Pavilion Addition     Manhasset
# 3     1000017965                             Confidential  Confidential
# 4     1000020194                  UMD New Cole Fieldhouse  College Park
# ...          ...                                      ...           ...
# 2061  1000215829         Canny Elevator Technology Center        Suzhou
# 2062  1000216346                         Mashreq Bank DOZ         Dubai
# 2063  1000216631      Commerzone Kharadi R1/Building No 3          Pune
# 2064  1000217225  Kama Ayurveda Factory, Crafting Greener      Tiruppur
# 2065  1000217729                         Central Square I       Chennai
#
#             State       Zipcode Country       RatingSystem  PointsAchieved  \
# ...

# %%
df_leed['City'] = df_leed['City'].str.lower()
df_leed
# Out:
#               ID                              ProjectName          City  \
# 0     1000011028               Clarksburg Fire Station 35    clarksburg
# 1     1000011315  Moultrie Courthouse - C Street Addition    washington
# 2     1000012868    Petrocelli Surgical Pavilion Addition     manhasset
# 3     1000017965                             Confidential  confidential
# 4     1000020194                  UMD New Cole Fieldhouse  college park
# ...          ...                                      ...           ...
# 2061  1000215829         Canny Elevator Technology Center        suzhou
# 2062  1000216346                         Mashreq Bank DOZ         dubai
# 2063  1000216631      Commerzone Kharadi R1/Building No 3          pune
# 2064  1000217225  Kama Ayurveda Factory, Crafting Greener      tiruppur
# 2065  1000217729                         Central Square I       chennai
#
#             State       Zipcode Country       RatingSystem  PointsAchieved  \
# ...

# %%
df_leed = df_leed.replace(to_replace='Confidential', value='CONF', regex=False)
df_leed
# Out:
#               ID                              ProjectName          City  \
# 0     1000011028               Clarksburg Fire Station 35    clarksburg
# 1     1000011315  Moultrie Courthouse - C Street Addition    washington
# 2     1000012868    Petrocelli Surgical Pavilion Addition     manhasset
# 3     1000017965                                     CONF  confidential
# 4     1000020194                  UMD New Cole Fieldhouse  college park
# ...          ...                                      ...           ...
# 2061  1000215829         Canny Elevator Technology Center        suzhou
# 2062  1000216346                         Mashreq Bank DOZ         dubai
# 2063  1000216631      Commerzone Kharadi R1/Building No 3          pune
# 2064  1000217225  Kama Ayurveda Factory, Crafting Greener      tiruppur
# 2065  1000217729                         Central Square I       chennai
#
#             State Zipcode Country       RatingSystem  PointsAchieved  \
# ...

# %% [raw]
# Create function to abbreviate City into 2 or 3 letters

# %%
df = pd.DataFrame({'City': [
    'clarksburg', 'washington', 'manhasset', 'college park', 'seropedica', 'los angeles', 'palatine', 'wise',
    'ellensburg', 'pittsburgh', 'riva del garda', 'new york','istanbul', 'queens', 'grayslake', 'silver spring', 'willows',
    'johnstown', 'joilet', 'miami', 'redding', 'french camp', 'brooklyn', 'leesburg', 'warren', 'hong kong', 'fishersville',
    'radford', 'changsha', 'gainesville', 'arlington', 'san francisco', 'faridabad', 'sherborn', 'bloomington', 'nashville', 'lubbock',
    'blacksburg', 'richmond', 'bowie', 'north bend', 'sylmar', 'boston', 'hayward', 'charlottesville', 'minneapolis', 'watertown',
    'towson', 'shenzhen', 'syracuse', 'lewiston', 'newport news', 'charlotte', 'long beach', 'dover', 'fairfax', 'sterling',
    'malmstrom', 'sweetwater', 'williamsburg', 'la jolla', 'chevy chase', 'trieste', 'warrenton', 'laurel', 'christmas',
    'philadelphia', 'newburyport', 'bangalore', 'harrisburg', 'ras al khaimah', 'harrisonburg', 'atlanta', 'winnipeg', 'calgary',
    'honolulu', 'cambridge', 'seattle', 'sacramento', 'brampton', 'chico', 'herndon', 'pyeongtaek-si', 'pleasant hill', 'antigonish',
    'montreal', 'avon', 'st-georges de beauce', 'lynnwood', 'san pablo', 'latrobe', 'new haven', 'denver', 'san luis obispo',
    'auburn', 'lexington', 'hanover', 'toronto', 'cincinnati', 'paramus', 'victoria', 'gambier', 'innisfail', 'fort belvoir',
    'heath', 'snoqualmie', 'grand rapids', 'muncie', 'san jose', 'san antonio', 'iowa city', 'santiago de queretaro', 'golden',
    'deerfield beach', 'columbus', 'monterosi', 'tampa', 'redmond', 'oakville', 'grafton', 'burlington', 'salamanca', 'middletown',
    'foshan', 'portland', 'abu dhabi', 'baltimore', 'raleigh', 'madrid', 'platteville', 'missoula', 'reading', 'springfield',
    'blue springs', 'notre dame', 'davis', 'tianjin', 'olesa de montserrat', 'austin', 'tekirdag', 'saint-laurent',
    'indianapolis', 'houston', 'highland heights', 'fredericksburg', 'columbia', 'ottawa', 'pasco', 'bologna', 'mont alto',
    'alexandria', 'dubai', 'west lafayette', 'des moines', 'milan', 'murrieta', 'barcelona', 'mchenry', 'south salt lake', 'renton',
    'valdagno', 'bay village', 'dayton', 'bronx', 'new carrollton', 'kepez', 'salt lake city', 'st. louis', 'hyderabad', 'qionglai',
    'new orleans', 'kitchener', 'jacksonville', 'ames', 'las cruces', 'sarasota', 'orlando', 'vienna', 'buffalo, ny', 'big rapids',
    'bellingham', 'las vegas', 'chong qing', 'cleveland', 'ann arbor', 'st. albert', 'san bruno', 'racine', 'mobile', 'marcy', 'mumbai',
    'mestre, venezia', 'morrison', 'austwell', 'oxford', 'fort myers', 'bluffdale', 'waterville', 'garden city', 'charleston', 'chehalis',
    'livermore', 'king of prussia', 'bellvue', 'annandale', 'coral gables', 'san diego', 'lukachukai', 'kunshan',
    'lawrenceville', 'nova andradina', 'chennai', 'fort lauderdale', 'elkton', 'bloomfield', 'ipswich', 'guangzhou', 'moab', 'concord',
    'ovindoli', 'granby', 'salisbury', 'pembroke pines', 'point mugu naval air station', 'asheville', 'everett', 'richland',
    'brighton', 'tucson', 'chattanooga', 'littleton', 'vancouver', 'fort collins', 'saint paul', 'bozeman', 'villanova', 'inglewood',
    'el paso', 'irvine', 'eugene', 'stamford, ct', 'fort lupton', 'blackstone', 'frankfort', 'taicang', 'bannockburn', 'hamden',
    'tacoma', 'lakewood', 'kiawah island', 'laval', 'phoenix', 'gloucester point', 'milano', 'vaudreuil', 'vallejo', 'jinan',
    'worcester', 'boulder', 'houghton', 'chongqing', 'reno', 'la puente', 'san mateo', 'reston', 'bellflower', 'wuxi',
    'cockeysville', 'coimbatore', 'foster city', 'riverside', 'saskatoon', 'kenmore', 'ponte vedra beach', 'west des moines',
    'brandenburg', 'bushnell', 'memphis', 'billings', 'pitkin county', 'basalt', 'reus', 'kansas city', 'turin', 'berea', 'merriam',
    'university park', 'okemos', 'changchun', 'spokane valley', 'tempe', 'sainte-adele', 'lynden', 'shanghai', 'tonganoxie',
    'miami beach', 'pompano beach', 'maringa', 'edmonds', 'chicago', 'sunnyvale', 'burdur', 'redwood city', 'pinghu', "xi'an",
    'steamboat springs', 'englewood', 'karapinar/ konya', 'lethbridge', 'roanoke', 'richardson', 'allendale', 'curtarolo', 'surat',
    'eau claire', 'naples', 'martinez', 'yongin-si', 'nokomos', 'greater noida', 'rahway', 'amasya', 'jiaxing',
    'salaberry-de-valleyfield', 'northlake', 'firenze', 'lincoln', 'kalamazoo', 'chengdu', 'universal city', 'borgomanero', 'dalmine',
    'citta santo angelo', 'buffalo', 'lonato del garda', 'rock hill', 'lonetree', 'adana', 'south san francisco', 'morrisville', 'lisle',
    'horsham', 'bellevue', 'antalya', 'erandio', 'yalova', 'monterey', 'madison', 'massa', 'arnavutkoy', 'foxborough', 'boise', 'lowell',
    'tijuana', 'mountain view', 'burgos', 'biella', 'suzhou city', 'alcobendas', 'brookings', 'venancio aires', 'champaign',
    'fairfield', 'delhi', 'fort worth', 'izmit', 'orhangazi', 'surrey', 'bursa', 'sao paulo', 'seongnam-si', 'clearwater', 'pinellas park',
    'elwood', 'palm coast', 'playa vista', 'canakkale', 'durgapur', 'kochi', 'pyeongtaek', 'mundra', 'chihuahua', 'lake oswego',
    'pune', 'park ridge', 'holland', 'wilmington', 'izmir', 'vigasio', 'queretaro', 'suzhou', 'sant cugat del valles', 'devens', 'seoul',
    'new delhi', 'beaumont', 'oragadam', 'wellesley', 'zhangjia gang', 'lake mary', 'pasadena', 'barueri', 'pozuelo de alarcon', '28010',
    'vaudreuil-dorion', 'pleasanton', 'tirupur', 'satara', 'brasilia', 'sao jose dos campos', 'changshu', 'gurgaon', 'cheongju-si',
    'hefei', 'beijing', 'corner brook', 'changzhou', 'noida', 'hangzhou', 'kahramanmaras', 'batman', 'elazig', 'sorocaba',
    'yongin', 'channahon', 'pensacola', 'agrate brianza', 'xiongan new area', 'cuautitlan izcalli',
    'esplugues de llobregat barcelona', 'san pedro garza garcia', 'mississauga', 'pali', 'ningbo', 'gautam buddh nagar',
    'ciudad de mexico', 'mexico city', 'gurugram', 'chungcheongnam-do', 'hk', 'central', 'hong kong island', 'irving', 'santa clara',
    'ajax', 'taegu', 'daegu', 'saint-hubert', 'westmount', 'las palmas de gran canaria', 'wuhan', 'washington, dc', 
    'edmonton', 'kernersville', 'high point', 'sandy springs', 'corum', 'rio de janeiro', 'hillsboro',
    'vasanthanarasapura , tumakuru, karnataka', 'needham', 'dallas', 'bengaluru', 'karur', 'compton', 'kokata', 'rome', 'roma',
    'marechal candido rondon', 'ulanqub city', 'santa barbara', 'krishnagiri district', 'foshan city', 'tarragona', 'gaithersburg',
    'apodaca', 'bharuch', 'nantong', 'xiangyang', 'cachoeira do sul', 'vadodara', 'curitiba', 'hosur', 'sulur', 'madurai', 'trichy',
    'kanadia', 'rajnandgaon', 'bhilai', 'yavatmal', 'patan', 'ankara', 'mugla', 'ordu', 'palanpur', 'mangaluru', 'ahmedabad',
    'surendra nagar', 'quarry bay', 'beverly hills', 'jajpur', 'porto belo', 'kolhapur', 'patiala', 'bradenton', 'carlsbad',
    'sri satya sai district', 'dongguan', 'cornella de llobregat', 'kolkata', 'rishra', 'nova veneza', 'medford', 'jandira', 'howrah',
    'falls church', 'banagalore', 'queimados', 'cajamar', 'aruja', 'seongnam', 'chandrapur', 'jaipur', 'parma', 'vimodrone',
    'etxebarri', 'sri city', 'ganjam district', 'tokat', 'san juan del rio', 'miami gardens', 'huizhou', 'al ain',
    'granada', "l'hospitalet de llobregat", 'newton', 'chelmsford', 'norfolk', 'bengaluru,', 'harbin', 'hohhot', 'ibiza',
    'albuquerque', 'kocaeli', 'nanjing', 'erode', 'sharjah', 'icheon-si, gyeonggi-do', 'cormano', 'colombo', 
    'prat de llobregat', 'moorpark', 'krishnagiri', 'atibaia', 'santana de parnaiba', 'shijiazhuang', 'qingdao', 'nanchong',
    'xian', 'haerbin', 'zhongshan', 'guiyang', 'nanchang', 'shenyang', 'yantai', 'zhengzhou', 'central, hong kong', 'durg', 'vijayawada',
    'navasari', 'mandsaur', 'indore', 'pithampur', 'jalandhar', 'ghaziabad', 'godhra', 'navsari', 'nashik', 'kaifeng',
    'mandi gobindgarh', 'gulbarga', 'nandurbar', 'manglore', 'dhule', 'panvel', 'udupi', 'thane', 'wardha', 'mancherial', 'nagpur',
    'mallorca', 'wenzhou', 'las rozas', 'kunming shi', 'chengalpattu', 'besiktas', 'pavia', 'andalucia', 'gurugram,', 'fujairah',
    'gautam buddha nagar', 'beyoglu', 'avcilar', 'uskudar', 'karatay', 'kwun tong', 'arco', 'priocca', 'savigliano', 'xiamen',
    'chaoyang district', 'kolar', 'fuzhou', 'tres cantos', 'ezhou', 'taikoo place, hong kong', 'lantau', 'tsim sha tsui',
    'zhujiang new town', 'yeoju-si', 'incheon', 'yuyao city', 'zhuhai', 'mapo-gu', 'goregaon', 'santander', 'gwangmyeong', 'siheung',
    'rohtak', 'icheon-si', 'tiruppur']})

#Abbreviation function
def abbreviate_city(city_name):
    words = city_name.strip().split()
    if len(words) == 1:
        return city_name[:3].upper()
    else:
        return ''.join(word[0].upper() for word in words)

# Apply and overwrite the City column
df_leed['City'] = df_leed['City'].apply(abbreviate_city)
df_leed
# Out:
#               ID                              ProjectName City        State  \
# 0     1000011028               Clarksburg Fire Station 35  CLA           MD
# 1     1000011315  Moultrie Courthouse - C Street Addition  WAS           DC
# 2     1000012868    Petrocelli Surgical Pavilion Addition  MAN           NY
# 3     1000017965                                     CONF  CON           MD
# 4     1000020194                  UMD New Cole Fieldhouse   CP           MD
# ...          ...                                      ...  ...          ...
# 2061  1000215829         Canny Elevator Technology Center  SUZ      Jiangsu
# 2062  1000216346                         Mashreq Bank DOZ  DUB           AE
# 2063  1000216631      Commerzone Kharadi R1/Building No 3  PUN  Maharashtra
# 2064  1000217225  Kama Ayurveda Factory, Crafting Greener  TIR   Tamil Nadu
# 2065  1000217729                         Central Square I  CHE   Tamil Nadu
#
# ...

# %%
not_abbr_states = df_leed.loc[~df_leed['State'].apply(is_state_abbreviated), 'State']
print(not_abbr_states)
# Out:
# 16         Istanbul
# 37            Hunan
# 38            Hunan
# 43          Haryana
# 52              N/A
#            ...
# 2060        Gujarat
# 2061        Jiangsu
# 2063    Maharashtra
# 2064     Tamil Nadu
# 2065     Tamil Nadu
# Name: State, Length: 1031, dtype: object

# %%
def abbreviate_state(state):
    state = state.strip()
    words = state.split()
    if len(words) == 1:
        return state[:3].upper()
    else:
        return ''.join(word[0].upper() for word in words)

def abbreviate_if_not(state):
    if len(state) == 2 and state.isupper():
        return state  
    else:
        return abbreviate_state(state)

df_leed['State'] = df_leed['State'].apply(abbreviate_if_not)
df_leed
# Out:
#               ID                              ProjectName City State Zipcode  \
# 0     1000011028               Clarksburg Fire Station 35  CLA    MD   20871
# 1     1000011315  Moultrie Courthouse - C Street Addition  WAS    DC   20001
# 2     1000012868    Petrocelli Surgical Pavilion Addition  MAN    NY   11030
# 3     1000017965                                     CONF  CON    MD    CONF
# 4     1000020194                  UMD New Cole Fieldhouse   CP    MD   20742
# ...          ...                                      ...  ...   ...     ...
# 2061  1000215829         Canny Elevator Technology Center  SUZ   JIA  215200
# 2062  1000216346                         Mashreq Bank DOZ  DUB    AE       0
# 2063  1000216631      Commerzone Kharadi R1/Building No 3  PUN   MAH  411060
# 2064  1000217225  Kama Ayurveda Factory, Crafting Greener  TIR    TN  641662
# 2065  1000217729                         Central Square I  CHE    TN  600032
#
# ...

# %%
df_leed.loc[df_leed['State'] == 'BAR', 'State'] = 'BCN'
df_leed['State'].unique()
# Out:
# array(['MD', 'DC', 'NY', 'RJ', 'CA', 'IL', 'VA', 'WA', 'PA', 'GU', 'TN',
#        'IST', 'TX', 'FL', 'AE', 'MI', 'NT', 'HUN', 'OH', 'HAR', 'MA',
#        'IN', 'N/A', 'NH', 'MO', 'MN', 'GUA', 'NC', 'DE', 'MT', 'TS', 'OR',
#        'KAR', 'HAI', 'GA', 'MB', 'AB', 'HI', 'ON', 'KYO', 'NS', 'QC',
#        'CO', 'CT', 'CAD', 'AL', 'KY', 'NJ', 'BC', 'UT', 'GOA', 'IA',
#        'QRO', 'VT', 'SP', 'SAL', 'MAD', 'WI', 'MS', 'BCN', 'TEK', 'BO',
#        'VI', 'ANT', 'TG', 'SIC', 'LA', 'NM', 'NV', 'CHO', 'RM', 'MAH',
#        'VE', 'SHA', 'ME', 'SC', 'AZ', 'JIA', 'AQ', 'TO', 'KS', 'SK', 'SD',
#        'TAR', 'PR', 'BUR', 'ZHE', 'KON', 'PD', 'GUJ', 'UP', 'AMA', 'FI',
#        'NE', 'NO', 'GAZ', 'BG', 'PE', 'BS', 'ADA', 'VIZ', 'YAL', 'KIR',
#        'ID', 'AR', 'BI', 'RS', 'DEL', 'KOC', 'RAJ', 'CAN', 'WB', 'KER',
#        'CHI', 'IZM', 'VR', 'SOU', 'DF', 'CHŽ', 'ANH', 'NL', 'K.M', 'BAT',
#        'MER', 'ELA', 'HK', 'MEX', 'TAE', 'LP', 'HUB', 'PG', 'COR', 'AP',
# ...

# %%
def clean_zipcode(z):
    z = str(z).strip()
    if z in ['0', '00000', '0000', '000000']:
        return 0
    if z.upper() == 'CONF':
        return 0
    try:
        return int(z)
    except ValueError:
        return 0  
df_leed['Zipcode'] = df_leed['Zipcode'].apply(clean_zipcode).astype(int)
df_leed.head(60)
# Out:
#             ID                               ProjectName City State  Zipcode  \
# 0   1000011028                Clarksburg Fire Station 35  CLA    MD    20871
# 1   1000011315   Moultrie Courthouse - C Street Addition  WAS    DC    20001
# 2   1000012868     Petrocelli Surgical Pavilion Addition  MAN    NY    11030
# 3   1000017965                                      CONF  CON    MD        0
# 4   1000020194                   UMD New Cole Fieldhouse   CP    MD    20742
# 5   1000024595                       PG Seropedica Genie  SER    RJ        0
# 6   1000026963       LA North Central Animal Care Ctr II   LA    CA    90031
# 7   1000027670               Harper College - Building D  PAL    IL    60067
# 8   1000028180                          UVA Wise Library  WIS    VA    24293
# 9   1000028301     Samuelson Bldg Renovation & Expansion  ELL    WA    98926
# 10  1000029009                                      CONF  CON    NY        0
# ...

# %%
df_leed['CertDate'] = pd.to_datetime(df_leed['CertDate'], errors='coerce', dayfirst=True)
df_leed['CertDate'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df_leed.to_csv('df_leed_cleaned.csv', index=False)
