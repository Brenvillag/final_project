# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("../data/clean/df_leed_cleaned.csv")
df.head()
# Out:
#            ID                              ProjectName City State  Zipcode  \
# 0  1000011028               Clarksburg Fire Station 35  CLA    MD    20871
# 1  1000011315  Moultrie Courthouse - C Street Addition  WAS    DC    20001
# 2  1000012868    Petrocelli Surgical Pavilion Addition  MAN    NY    11030
# 3  1000017965                                     CONF  CON    MD        0
# 4  1000020194                  UMD New Cole Fieldhouse   CP    MD    20742
#
#   Country   RatingSystem  PointsAchieved CertLevel    CertDate IsCertified  \
# 0      US  LEED-NC v2009              52    Silver  2024-11-20         Yes
# 1      US  LEED-NC v2009              81  Platinum  2024-08-30         Yes
# 2      US  LEED-NC v2009              53    Silver  2024-08-08         Yes
# 3      US  LEED-NC v2009              52    Silver  2024-08-07         Yes
# 4      US  LEED-NC v2009              57    Silver  2024-11-08         Yes
#
# ...

# %%
df = df.rename(columns={'ID': 'Project_Id'})
df
# Out:
#       Project_Id                              ProjectName City State  Zipcode  \
# 0     1000011028               Clarksburg Fire Station 35  CLA    MD    20871
# 1     1000011315  Moultrie Courthouse - C Street Addition  WAS    DC    20001
# 2     1000012868    Petrocelli Surgical Pavilion Addition  MAN    NY    11030
# 3     1000017965                                     CONF  CON    MD        0
# 4     1000020194                  UMD New Cole Fieldhouse   CP    MD    20742
# ...          ...                                      ...  ...   ...      ...
# 2061  1000215829         Canny Elevator Technology Center  SUZ   JIA   215200
# 2062  1000216346                         Mashreq Bank DOZ  DUB    AE        0
# 2063  1000216631      Commerzone Kharadi R1/Building No 3  PUN   MAH   411060
# 2064  1000217225  Kama Ayurveda Factory, Crafting Greener  TIR    TN   641662
# 2065  1000217729                         Central Square I  CHE    TN   600032
#
# ...

# %%
df.isnull().sum()
# Out:
# Project_Id             0
# ProjectName            0
# City                   1
# State                182
# Zipcode                0
# Country                0
# RatingSystem           0
# PointsAchieved         0
# CertLevel              0
# CertDate               0
# IsCertified            0
# GrossFloorAreaSqm      0
# ProjectTypes           0
# dtype: int64

# %%
for index, row in df[df['City'].isna()].iterrows():
    print(f"Row {index}: {row.to_dict()}")
# Out:
# Row 374: {'Project_Id': 1000132841, 'ProjectName': 'Viposa - NOA', 'City': nan, 'State': 'MS', 'Zipcode': 0, 'Country': 'BR', 'RatingSystem': 'LEED v4 BD+C: NC', 'PointsAchieved': 52, 'CertLevel': 'Silver', 'CertDate': '2024-07-25', 'IsCertified': 'Yes', 'GrossFloorAreaSqm': 12186.0, 'ProjectTypes': 'Industrial Manufacturing'}

# %%
df['City'] = df['City'].fillna('NOA')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2066 entries, 0 to 2065
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Project_Id         2066 non-null   int64
#  1   ProjectName        2066 non-null   object
#  2   City               2066 non-null   object
#  3   State              1884 non-null   object
#  4   Zipcode            2066 non-null   int64
#  5   Country            2066 non-null   object
#  6   RatingSystem       2066 non-null   object
#  7   PointsAchieved     2066 non-null   int64
#  8   CertLevel          2066 non-null   object
#  9   CertDate           2066 non-null   object
#  10  IsCertified        2066 non-null   object
#  11  GrossFloorAreaSqm  2066 non-null   float64
#  12  ProjectTypes       2066 non-null   object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 210.0+ KB

# %%
for index, row in df[df['State'].isna()].iterrows():
    print(f"Row {index}: {row.to_dict()}")
# Out:
# Row 52: {'Project_Id': 1000070502, 'ProjectName': 'CONF', 'City': 'CON', 'State': nan, 'Zipcode': 0, 'Country': 'CN', 'RatingSystem': 'LEED-NC v2009', 'PointsAchieved': 61, 'CertLevel': 'Gold', 'CertDate': '2024-06-10', 'IsCertified': 'Yes', 'GrossFloorAreaSqm': 59197.35, 'ProjectTypes': 'CONF'}
# Row 211: {'Project_Id': 1000118400, 'ProjectName': 'BTC Phase III construction', 'City': 'TIA', 'State': nan, 'Zipcode': 300451, 'Country': 'CN', 'RatingSystem': 'LEED v4 BD+C: NC', 'PointsAchieved': 67, 'CertLevel': 'Gold', 'CertDate': '2024-02-20', 'IsCertified': 'Yes', 'GrossFloorAreaSqm': 577512.0, 'ProjectTypes': 'Industrial Manufacturing'}
# Row 212: {'Project_Id': 1000118401, 'ProjectName': 'Administration Building of BTC', 'City': 'TIA', 'State': nan, 'Zipcode': 300451, 'Country': 'CN', 'RatingSystem': 'LEED v4 BD+C: NC', 'PointsAchieved': 85, 'CertLevel': 'Platinum', 'CertDate': '2024-05-15', 'IsCertified': 'Yes', 'GrossFloorAreaSqm': 75300.0, 'ProjectTypes': 'Office: Mixed-Use'}
# ...

# %%
#Create Location Table (filter columns)
#location_df = df[['City', 'State', 'Zipcode', 'Country']]
#location_df

# %%
#location_df['numbers'] = location_df.groupby('City').cumcount() + 1

# Convert number to int before concatenating
#location_df['Location_Id'] = location_df['City'] + location_df['numbers'].astype(int).astype(str)

# Drop helper column
#location_df = location_df.drop(columns=['numbers'])
